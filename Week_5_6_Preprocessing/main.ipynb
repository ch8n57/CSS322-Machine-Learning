# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

# %%
# Load dataset
df = pd.read_csv("electricity_usage.csv", na_values='?')

# %%
print("Missing Values:\n", df.isnull().sum(), "\n")
print("Statistical Summary:\n", df.describe(), "\n")
# Out:
# Missing Values:
#  House_ID                           0
#  Monthly_Avg_Consumption (kWh)     0
#  Peak_Consumption (kWh)            0
#  Owner_Type (Local/NRI/Retired)    0
#  House_Age (years)                 0
#  Distance_to_Substation (km)       0
#  House_Value (Lakhs)               0
#  Low_Usage_Flag                    0
# dtype: int64
#
# Statistical Summary:
#         Peak_Consumption (kWh)  House_Age (years)  House_Value (Lakhs)
# count                 5.00000           5.000000             5.000000
# mean               1210.00000           8.200000           148.000000
# std                1567.00351           4.658326           128.724512
# min                 300.00000           3.000000            40.000000
# 25%                 450.00000           5.000000            60.000000
# 50%                 600.00000           8.000000            90.000000
# 75%                 700.00000          10.000000           200.000000
# ...

# %%
Q1 = df['Peak_Consumption (kWh)'].quantile(0.25)
Q3 = df['Peak_Consumption (kWh)'].quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\yadun\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Peak_Consumption (kWh)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ...
